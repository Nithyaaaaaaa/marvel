# %% [markdown]
# # Task 20: Notebook Ninja – Getting Started with Jupyter
#
# ## Introduction
# Welcome to my first Jupyter Notebook!
# In this task, I explored both **Markdown** and **Python** features to make my work clean, readable, and professional.
#
# ---
#
# ### Goals:
# Here are 3 things I want to learn:
# - How to use Markdown effectively for clear documentation
# - How to combine code and visuals for storytelling
# - How to keep notebooks structured and easy to follow
#
# ---
#
# ### Formating Text:
# - **Bold**
# - *Italics*
# - Underline ---
#
# ### Embedded Image:
# ![Bob](https://toppng.com/uploads/preview/minions-png-transparent-image-minion-stuart-11562979774dj95rhdovq.png)
#
# ### Code Snippet:
#
# a=10
# b=5
# print(a-b)

# %%
a = 10
b = 5
result = a + b
print("The sum is:", result)
# Out:
# The sum is: 15

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.plot(x, y)
plt.title("Graph of y = x^2")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Summary
#
# Through this task, I learned how to:
#
# - Use **Markdown** for clear documentation (headings, formatting, lists, images, and code snippets)
# - Write simple **Python code** for calculations
# - Create basic **visualizations** using Matplotlib
# - Keep my notebook organized and easy to read
